# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
car1=pd.read_csv('cars1(Merge).csv')
car2=pd.read_csv('cars2(Merge).csv')
car1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
car2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
car1.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  198.000000  198.000000    198.000000   198.000000    198.000000
# mean    19.719697    5.898990    223.469697  3177.888889     15.005556
# std      5.814254    1.785417    115.181017   934.783733      2.872382
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     15.000000    4.000000    113.250000  2302.500000     13.000000
# 50%     19.000000    6.000000    228.000000  3030.000000     15.000000
# 75%     24.375000    8.000000    318.000000  4080.750000     16.800000
# max     35.000000    8.000000    455.000000  5140.000000     23.500000
#
#             model      origin  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# count  198.000000  198.000000         0.0          0.0          0.0
# mean    72.818182    1.439394         NaN          NaN          NaN
# std      1.865332    0.708085         NaN          NaN          NaN
# ...

# %%
car1.drop(['Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'],axis=1,inplace=True)
car1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(car1.shape)
print(car2.shape)
# Out:
# (198, 9)
# (200, 9)

# %%
car1.value_counts()
print(car1.value_counts())
print(car2.value_counts())
# Out:
# mpg   cylinders  displacement  horsepower  weight  acceleration  model  origin  car
# 9.0   8          304           193         4732    18.5          70     1       hi 1200d                     1
# 22.0  4          122           86          2395    16.0          72     1       ford pinto (sw)              1
#       6          198           95          2833    15.5          70     1       plymouth duster              1
#                  225           100         3233    15.4          76     1       plymouth valiant             1
#                  250           105         3353    14.5          76     1       chevrolet nova               1
#                                                                                                             ..
# 16.0  6          250           105         3897    18.5          75     1       chevroelt chevelle malibu    1
#                  258           110         3632    18.0          74     1       amc matador                  1
# ...

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.concat([car1,car2],axis=0)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
x=np.random.randint(low=15000,high=73000,size=398)
print(x)
# Out:
# [60119 36709 69865 27702 54940 30399 35928 70941 55879 37043 72061 57039
#  26899 57379 53479 31647 54396 61375 55618 15631 35887 60272 35734 32150
#  52597 62344 27371 43738 58443 57441 30716 38482 50877 31560 46690 70359
#  24006 53502 50110 67278 16832 59818 34331 72136 16483 70921 30602 72041
#  42186 22981 25846 58271 30719 63739 38899 36269 26011 37272 30266 70666
#  42004 55783 68959 58541 50336 42251 41583 46752 32554 55927 41731 64121
#  62371 55776 72761 38762 29133 29523 20800 51490 36321 24395 49653 71703
#  42366 25986 72049 37555 63848 24251 49319 38507 51179 15004 16909 26487
#  72026 25631 45126 54430 70404 64655 36629 29164 65478 66064 16152 43810
#  43952 21591 40250 27486 33312 18070 49202 39021 42153 29047 18078 37730
#  37782 65167 24325 65816 55806 20800 69722 69363 29615 31776 28201 62604
#  37614 50328 48651 46560 65390 21525 27225 54661 34953 55112 19664 26200
#  43215 38060 27744 41396 24441 56587 51752 49801 21882 34748 50587 29598
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners']=x
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...
